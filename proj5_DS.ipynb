# %% [markdown]
# # INFO 2950 Project
#
# ## Introduction (NEED TO EXPAND)
#
# Our research question/goal is to successfully measuring a NBA player's ability to induce and convert offensive opportunities for himself, as well as leading teammates to those opportunities. In other words, we are attempting to measure how good a player is at creating and efficiently making shots for himself, and at making plays that lead to points for his teammates.

# %% [markdown]
# ## Data Description
#
# 1. For what purpose was the dataset created? Was there a specific task in mind? Was there a specific gap that needed to be filled? Please provide a description.
#
# The dataset was created with the purpose of being used for NBA player evaulation and specific skill analysis. While there may have not been a specific gap that needed to be filled, this dataset (and other similar to it) have allowed for far more advanced evaluation of a player's ability and specific skillset than done even as recently as about a decade ago. Furthermore, this data has been made far more accessible to people outside of the industry.
#
# 2. Who created the dataset (e.g., which team, research group) and on behalf of which entity (e.g., company, institution, organization)? Who funded the creation of the dataset? If there is an associated grant, please provide the name of the grantor and the grant name and number.
#
# Sports Reference, LLC. created most of our dataset, while the rest was created by Darryl Blackport. Sports Reference's mission, as can be found on the "About" portion of their website, is to "promote the democratization of sports data". Blackport's reason behind creating pbpstats.com stems from the fact that there "is lots of information available in play-by-play data but a lot of it isn't readily available without the programming skills to clean the raw data." He created this data source "to make some of this information more accessible to NBA, WNBA and G-League fans looking for stats beyond the boxscore".
#
# 3. What do the instances that comprise the dataset represent (e.g., documents, photos, people, countries)? Are there multiple types of instances (e.g., movies, users, and ratings; people and interactions be- tween them; nodes and edges)? Please provide a description.
#
# Each instance represents an NBA player during a single season. Thus, many players are represented by multiple instances in the dataset. For example, LeBron James has played in every season since the 2003-2004 season. So, each seasonal version of James is contained within its own instance.
#
# 4. How many instances are there in total (of each type, if appropriate)?
#
# There are 6,717 instances in total.
#
# 5. Does the dataset contain all possible instances or is it a sample (not necessarily random) of instances from a larger set? If the dataset is a sample, then what is the larger set? Is the sample representa- tive of the larger set (e.g., geographic coverage)? If so, please describe how this representativeness was validated/verified. If it is not representative of the larger set, please describe why not (e.g., to cover a more diverse range of instances, because instances were withheld or unavailable).
#
# The dataset contains all NBA players that played in any season from the 2000-2001 season to the 2020-2021 season. Furthermore, the dataset is restricted to players above the 30th percentile in minutes played in each of those seasons. This is due to a few reasons. The first, and primary, reason is because some of our data was not available for many players whose minutes played placed them below the cutoff. Additionally, per-possession and existing advanced statistics are subject to extreme noise when examined for players with lower amounts of minutes played, as these small sample sizes are not representative of a player’s true ability and are often strongly influenced by external factors.
#     Furthermore, we restricted our dataset to include players only from the past 20 seasons because some of the data, which we believe to make a rather significant difference in the accuracy of our statistic, is only available for players who played in the 2000-2001 season or later.
#
# 6. What data does each instance consist of? “Raw” data (e.g., unpro- cessed text or images) or features? In either case, please provide a description.
#
# Each instance consists of numerical values describing a player’s seasonal performance, as well as categorical values describing the player himself. The following features are present for each instance in the dataset:.Our curated, final dataset can be found here:.
#
# 7. Is any information missing from individual instances? If so, please provide a description, explaining why this information is missing (e.g., because it was unavailable). This does not include intentionally removed information, but might include, e.g., redacted text.
#
# There is not any information missing from individual instances.
#
# 8. Are relationships between individual instances made explicit (e.g., users’ movie ratings, social network links)? If so, please de- scribe how these relationships are made explicit.
#
# Relationships between individual instances are not made explicit.
#
# 9. Are there recommended data splits (e.g., training, development/validation, testing)? If so, please provide a description of these splits, explaining the rationale behind them.
#
# There are no recommended data splits.
#
# 10. Are there any errors, sources of noise, or redundancies in the dataset? If so, please provide a description.
#
# There are no errors, sources of noise, or redundancies in the dataset.
#
# 11. Is the dataset self-contained, or does it link to or otherwise rely on external resources (e.g., websites, tweets, other datasets)? If it links to or relies on external resources, a) are there guarantees that they will exist, and remain constant, over time; b) are there official archival versions of the complete dataset (i.e., including the external resources as they existed at the time the dataset was created); c) are there any restrictions (e.g., licenses, fees) associated with any of the external resources that might apply to a future user? Please provide descriptions of all external resources and any restrictions associated with them, as well as links or other access points, as appropriate.
#
# As previously alluded to, the dataset relies on external resources. The external resources relied upon are called Stathead Basketball (via Sports Reference, LLC) and PBP Stats.
#
# Stathead Basketball is a powerful, highly regarded sports research tool. For our data from Stathead Basketball from the 2017-2018 season to the 2020-2021 season, we gathered it directly from the site using its Player Season Finder tool. However, Stathead is a subscription-based service, so users without a paid subscription will not be able to obtain the data directly through Stathead (https://stathead.com/basketball/). However, for all seasons prior to the 2017-2018 season, we obtained the same data we would have through Stathead itself from an already created dataset found on Kaggle (https://www.kaggle.com/drgilermo/nba-players-stats) which was used for a different project. This dataset was obtained by scraping Basketball Reference, which is the site that hosts Stathead Basketball.
#
# PBP Stats is another highly regarded sports research tool. All of the data it utilizes is from data.nba.com and stats.nba.com, which both contain basically the same data, albeit with the following small differences, according to PBP Stats creator Darryl Blackport: “The data.nba.com play-by-play has the offense team id in all events, which makes it easier to track possession changes. The stats.nba.com events do not have this attribute and to get possession counts the play-by-play needs to be parsed, which makes it more sensitive to events being in the correct order. The stats.nba.com play-by-play also has lots of shots and rebounds that are out of order that need to be fixed manually. If you download the data from the link above, I have fixed these for previous seasons, but going forward if you use this you will have to keep up with fixing them manually yourself. If you don’t care if there may be an occasional possession count being off or you don’t want to deal with manually fixing the event order I suggest using data.nba.com for your play-by-play provider…” additionally, “stats.nba.com has more older season data available, and “the data.nba.com play-by-play updates in real time” (https://pbpstats.readthedocs.io/_/downloads/en/v1.1.2/pdf/). All of the data we collected from PBP Stats (http://www.pbpstats.com/) is accessible by, from the home page, selecting “Totals” and then “Player”. The tables we utilized were the “Scoring” and the “Assists” tables for every season available.
#
# 12. Does the dataset contain data that might be considered confiden- tial (e.g., data that is protected by legal privilege or by doctor- patient confidentiality, data that includes the content of individu- als’ non-public communications)? If so, please provide a description.
#
# The dataset does not contain data that might be considered confidential.
#
# 13. Does the dataset contain data that, if viewed directly, might be of- fensive, insulting, threatening, or might otherwise cause anxiety? If so, please describe why.
#
# The dataset does not contain data that might be offensive, insulting, threatening, or cause anxiety in any other way.
#
# 14. Does the dataset relate to people? If not, you may skip the remaining questions in this section.
#
# Yes, the dataset relates to people.
#
# 15. Does the dataset identify any subpopulations (e.g., by age, gen- der)? If so, please describe how these subpopulations are identified and provide a description of their respective distributions within the dataset. Is it possible to identify individuals (i.e., one or more natural per- sons), either directly or indirectly (i.e., in combination with other data) from the dataset? If so, please describe how.
#
# The dataset does not identify any subpopulations.
#
# 16. Does the dataset contain data that might be considered sensitive in any way (e.g., data that reveals racial or ethnic origins, sexual orientations, religious beliefs, political opinions or union mem- berships, or locations; financial or health data; biometric or ge- netic data; forms of government identification, such as social se- curity numbers; criminal history)? If so, please provide a description.
#
# The dataset does not contain data that might be considered sensitive in any way.
#
# 17. How was the data associated with each instance acquired? Was the data directly observable (e.g., raw text, movie ratings), reported by subjects (e.g., survey responses), or indirectly inferred/derived from other data (e.g., part-of-speech tags, model-based guesses for age or language)? If data was reported by subjects or indirectly inferred/derived from other data, was the data validated/verified? If so, please describe how.
#
# Starting with the 2018-2019 season, all of the data on Stathead is official NBA data provided by SportRadar, the official statistics partner of the NBA. For seasons prior to 2018-2019, the data is official NBA data entered, maintained, and updated by Sports Reference employees.
# All of the data on PBP Stats was collected by web-scraping and other programming tools.
#
# 18. Does the dataset relate to people? If not, you may skip the remainder of the questions in this section.
#
# Yes, the dataset relates to people.
#
# 19. Did you collect the data from the individuals in question directly, or obtain it via third parties or other sources (e.g., websites)?
#
# The data was collected via other sources.
#
# 20. Was the “raw” data saved in addition to the preprocessed/cleaned/labeled data (e.g., to support unanticipated future uses)? If so, please provide a link or other access point to the “raw” data.
#
# The “raw” data can be found here: https://drive.google.com/drive/folders/1IhxZATJ3L_053bhfZfvgzClR9FXLLeF7.
#
# 21. Has the dataset been used for any tasks already? If so, please provide a description.
#
# The entire dataset has not been used for any tasks yet.
#
# 22. What (other) tasks could the dataset be used for?
#
# The dataset can be used for many basketball analyses, assuming the analyses require the slight scope limitations that our dataset uses.
#
# 23. Is there anything about the composition of the dataset or the way it was collected and preprocessed/cleaned/labeled that might im- pact future uses? For example, is there anything that a future user might need to know to avoid uses that could result in unfair treatment of individuals or groups (e.g., stereotyping, quality of service issues) or other undesirable harms (e.g., financial harms, legal risks) If so, please provide a description. Is there anything a future user could do to mitigate these undesirable harms?
#
# There is nothing about the composition of the dataset or the way it was collected and cleaned that might impact future uses.
#
# 24. Are there tasks for which the dataset should not be used? If so, please provide a description.
#
# Depending on the desired period of analysis, this dataset may not be good for historical player analysis. Since the data only goes back to the 2000-2001 season, if one wished to analyze individual player seasons during the 21st century exclusively, then this dataset would be fine. However, any further back and this dataset will not be great. Furthermore, while certain statistics for certain players present in the dataset could be analyzed from the career-level utilizing this dataset, it's far more useful as a tool to analyze individual seasons of player careers.

# %% [markdown]
# ## Preregistration Statement
#
# 1. One analysis we will perform is an examination of how strong of a predictor our statistic is of a given player's position. To do this, we will perform multi-class logistic regression, using our statistic as the input variable. The model will predict a given player's position to be guard (G), forward (F), or center (C). Furthermore, we will use a train-test split to prevent overfitting.
#
# 2. A second analysis we will perform is a multivariate regression on the player rankings derived from ‘obpm’ values. This will be a basic multivariate model based on Offensive Box Plus-Minus (OBPM),  a popular advanced statistic. The results of this regression task will help inform us in the creation and further analysis of our own advanced statistic. The independent variables in the regression will be unassisted points, which will be a sum of ‘ptsunassisted2s’ and ‘ptsunassisted3s’, ‘assistpoints’, and ‘ts%’. In theory, these 3 variables should be strong indicators of player performance, so we wanted to know the magnitude and significance of their effect on a player’s league-wide ranking.

# %% [markdown]
# ## Data Analysis

# %%
# Load the libraries necessary for our analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report, f1_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import statsmodels.formula.api as smf
# %matplotlib inline

# %%
# Read in our cleaned data
nba = pd.read_csv('nba.csv')
lg_avg_shooting = pd.read_csv('lg_avg_shooting.csv')
teamstats = pd.read_csv('teamstats.csv')
lg_avg_teamstats = pd.read_csv('lg_avg_teamstats.csv')

# %%
# Now, before continuning, for all of our dfs besides nba, let's set (at least one) index to be the season column.
lg_avg_shooting = lg_avg_shooting.set_index('season')
lg_avg_teamstats = lg_avg_teamstats.set_index('season')
teamstats['index'] = teamstats.index
teamstats = teamstats.set_index(['index','season'])
# One example of what we just did...
teamstats
# Out:
#               rank team  age  wins  losses  pw  pl    mov   sos    srs  ...  \
# index season                                                            ...
# 0     2001       1  SAS   29    58      24  63  19   7.76  0.16   7.92  ...
# 1     2001       2  SAC   27    55      27  57  25   5.82  0.25   6.07  ...
# 2     2001       3  UTA   32    53      29  55  27   4.70  0.31   5.00  ...
# 3     2001       4  PHI   28    56      26  54  28   4.28 -0.65   3.64  ...
# 4     2001       5  POR   30    50      32  53  29   4.20  0.33   4.52  ...
# ...            ...  ...  ...   ...     ...  ..  ..    ...   ...    ...  ...
# 621   2021      26  MIN   23    23      49  24  48  -5.56  0.31  -5.25  ...
# 622   2021      27  HOU   26    17      55  20  52  -7.90  0.40  -7.50  ...
# 623   2021      28  CLE   24    22      50  18  54  -8.44  0.25  -8.19  ...
# 624   2021      29  ORL   25    21      51  17  55  -9.31  0.29  -9.02  ...
# 625   2021      30  OKC   22    22      50  15  57 -10.64  0.51 -10.13  ...
#
#                efg%  tov%  orb%  ft/fga  efg%.1  tov%.1  drb%  ft/fga.1  \
# index season
# 0     2001    0.496  13.6  27.1   0.267   0.444    12.9  73.7     0.182
# 1     2001    0.484  13.4  27.2   0.230   0.460    14.5  70.7     0.181
# 2     2001    0.497  15.1  30.2   0.273   0.473    15.6  73.2     0.301
# 3     2001    0.468  14.7  31.2   0.262   0.460    14.5  72.5     0.186
# 4     2001    0.497  14.8  30.0   0.225   0.470    14.3  72.4     0.223
# ...             ...   ...   ...     ...     ...     ...   ...       ...
# 621   2021    0.520  12.4  22.7   0.193   0.556    13.3  76.8     0.207
# 622   2021    0.521  13.0  19.8   0.187   0.555    12.9  77.1     0.201
# 623   2021    0.508  13.9  23.6   0.194   0.556    13.0  76.6     0.183
# 624   2021    0.490  11.5  21.6   0.186   0.547    11.5  78.2     0.169
# 625   2021    0.509  14.2  21.2   0.176   0.547    11.5  77.9     0.167
#
#                attend.  attend./g
# index season
# 0     2001    913176.0    22273.0
# 1     2001    709997.0    17317.0
# 2     2001    792196.0    19322.0
# 3     2001    805692.0    19651.0
# 4     2001    831376.0    20277.0
# ...                ...        ...
# 621   2021     15774.0      438.0
# 622   2021    117009.0     3250.0
# 623   2021     91476.0     2541.0
# 624   2021    126463.0     3513.0
# 625   2021         NaN        NaN
#
# [626 rows x 27 columns]

# %% [markdown]
# In the above cell, we altered the index of the 3 DataFrames not named "nba" such that their rows were either partially or exclusively indexed by the season where the observation is from. The DataFrame teamstats' observations cannot be exclusively indexed by season because each season has as many observations as there were NBA teams at the time. We could not do this in the Appendix because writing the index to the csv would have resulted in our DataFrames having an unnamed column for the index when read back in, but they would still be indexed using the Pandas default.

# %% [markdown]
# ### I. Creating Our Statistic

# %% [markdown]
# In this portion of our project, we create our statistic, which is called "Self Induced Offense Measurement", or "SIOM". In its final, standardized form, we refer to it as "rSIOM", where the lower case r stands for "relative".

# %%
# Creating a new df to calculate and store the expected value of shots from 0-3 ft, 3-10 ft, 10-16 ft, 
# 16 ft to the 3PT line, corner 3s, and arc 3s for each individual season...
expected_values_by_loc = lg_avg_shooting.copy()
# Need to find % 3PA from arc (non-corner) and Arc 3PM %
expected_values_by_loc['pct_3pa_arc'] = 1 - expected_values_by_loc['pct_3pa_corner']
# Now, using the fact that overall 3PM % is a weighted average of arc and corner 3PM %, we know that...
expected_values_by_loc['pct_3pm_arc'] = round(((expected_values_by_loc['pct_3pm'] - 
                                        (expected_values_by_loc['pct_3pm_corner']*
                                         expected_values_by_loc['pct_3pa_corner']))/expected_values_by_loc['pct_3pa_arc']),3)
expected_values_by_loc.head(5)
# Out:
#         pct_fga_2p  pct_fga_3to10_ft  pct_fga_10to16_ft  pct_2pm  \
# season
# 2021         0.608             0.186              0.096    0.530
# 2020         0.616             0.165              0.093    0.524
# 2019         0.641             0.162              0.096    0.520
# 2018         0.663             0.156              0.106    0.510
# 2017         0.684             0.152              0.099    0.503
#
#         pct_fgm_0to3_ft  pct_fgm_3to10_ft  pct_fgm_10to16_ft  \
# season
# 2021              0.675             0.428              0.435
# 2020              0.667             0.396              0.416
# 2019              0.658             0.400              0.413
# 2018              0.658             0.394              0.415
# 2017              0.631             0.414              0.412
#
#         pct_fgm_16ftto3pt  pct_3pm  pct_2pm_assisted  pct_3pm_assisted  \
# season
# 2021                0.409    0.367             0.502             0.826
# 2020                0.404    0.358             0.504             0.815
# 2019                0.401    0.355             0.513             0.823
# 2018                0.400    0.362             0.499             0.830
# 2017                0.403    0.358             0.495             0.835
#
#         pct_3pa_corner  pct_3pm_corner  pct_3pa_arc  pct_3pm_arc
# season
# 2021             0.222           0.395        0.778        0.359
# 2020             0.211           0.390        0.789        0.349
# 2019             0.214           0.383        0.786        0.347
# 2018             0.208           0.394        0.792        0.354
# 2017             0.228           0.388        0.772        0.349

# %% [markdown]
# In the above cell, we created a new DataFrame expected_values_by_loc which will contain the expected value of shots from various locations on the floor from 2000 to 2021. Furthermore, we created two columns which were not present in our read-in data `pct_3pa_arc` and `pct_3pm_arc`, which contains the league average percentage of 3s taken that were not in the corner and the conversion rate of non-corner 3s by season, respectively.

# %%
# Now, finding the expected values...
expected_values_by_loc['ev_0to3ft'] = 2*(expected_values_by_loc['pct_fgm_0to3_ft'])
expected_values_by_loc['ev_3to10ft'] = 2*(expected_values_by_loc['pct_fgm_3to10_ft'])
expected_values_by_loc['ev_10to16ft'] = 2*(expected_values_by_loc['pct_fgm_10to16_ft'])
expected_values_by_loc['ev_16ftto3pt'] = 2*(expected_values_by_loc['pct_fgm_16ftto3pt'])
expected_values_by_loc['ev_3pt_corner'] = 3*(expected_values_by_loc['pct_3pm_corner'])
expected_values_by_loc['ev_3pt_arc'] = 3*(expected_values_by_loc['pct_3pm_arc'])
expected_values_by_loc

# Removing all unnecessary columns from expected_values_by_loc...
expected_values_by_loc = expected_values_by_loc.loc[:,['ev_0to3ft', 'ev_3to10ft', 'ev_10to16ft',
                                                       'ev_16ftto3pt', 'ev_3pt_corner', 'ev_3pt_arc']]
expected_values_by_loc.head(5)
# Out:
#         ev_0to3ft  ev_3to10ft  ev_10to16ft  ev_16ftto3pt  ev_3pt_corner  \
# season
# 2021        1.350       0.856        0.870         0.818          1.185
# 2020        1.334       0.792        0.832         0.808          1.170
# 2019        1.316       0.800        0.826         0.802          1.149
# 2018        1.316       0.788        0.830         0.800          1.182
# 2017        1.262       0.828        0.824         0.806          1.164
#
#         ev_3pt_arc
# season
# 2021         1.077
# 2020         1.047
# 2019         1.041
# 2018         1.062
# 2017         1.047

# %% [markdown]
# In the above cell, we calculated and put into columns the expected value of shots from six different areas on the court for every season in our dataset (2000-2001 through 2020-2021) and then removed unnecessary columns from our DataFrame which contains the aforementioned expecrted values.

# %% [markdown]
# Note that pbpstats classifies short mid-range shots as shots from 4-14 ft away from the basket and long mid-range as coming from 14 ft away from the basket to the three point line. Because of how the Basketball Reference league average shooting data is broken up, we will have to define short mid-range as 3-16 ft away and long mid-range as 16 ft away to the three point line. Looking at the percentages in our lg_avg_shooting DataFrame, this re-classification should not alter our results significantly. In the below cell, we adjust our expected_values_by_loc DataFrame.

# %%
# Adjusting for reclassification
for i in list(lg_avg_shooting.index.values):
    expected_values_by_loc.loc[i,'estev_3to16ft'] = round((((lg_avg_shooting.loc[i,'pct_fga_3to10_ft']/(lg_avg_shooting.loc[i,'pct_fga_3to10_ft'] 
                                                       + lg_avg_shooting.loc[i,'pct_fga_10to16_ft']))*expected_values_by_loc.loc[i,'ev_3to10ft']) 
                                                       + ((lg_avg_shooting.loc[i,'pct_fga_10to16_ft']/(lg_avg_shooting.loc[i,'pct_fga_3to10_ft'] 
                                                       + lg_avg_shooting.loc[i,'pct_fga_10to16_ft']))*expected_values_by_loc.loc[i,'ev_10to16ft'])),3)
expected_values_by_loc.head(5)
# Out:
#         ev_0to3ft  ev_3to10ft  ev_10to16ft  ev_16ftto3pt  ev_3pt_corner  \
# season
# 2021        1.350       0.856        0.870         0.818          1.185
# 2020        1.334       0.792        0.832         0.808          1.170
# 2019        1.316       0.800        0.826         0.802          1.149
# 2018        1.316       0.788        0.830         0.800          1.182
# 2017        1.262       0.828        0.824         0.806          1.164
#
#         ev_3pt_arc  estev_3to16ft
# season
# 2021         1.077          0.861
# 2020         1.047          0.806
# 2019         1.041          0.810
# 2018         1.062          0.805
# 2017         1.047          0.826

# %% [markdown]
# In the below cell, we find the `rSIOM` values for each player season present in our dataset. `rSIOM` is made up of two sub-metrics we've calculated, `siom_self_factor` and `siom_others_factor`. `siom_self_factor` is a measure of a player's self-induced scoring, while `siom_others_factor` is a measure of a player's playmaking. Both factors take into account both efficiency and production.
#
# Additionally, after summing both factors, two further adjustments are made before getting our final unstandardized `siom` values. These adjustments are for player Usage Rate (`usg%`) and for player Pace (`pace_estimate`). This is to prevent our statistic from favoring players who use a higher proportion of their team possesions while on the floor (which is measured by Usage Rate) or who have a larger number of possesions to produce points (which is measured by Pace). This is because while production is significant, our statistic aims to measure a player's ability to induce offense, which is not the same as capturing a player's production while in that role.

# %%
# Piece-by-piece building of our statistic
nba_groups = nba.groupby('season')
siom_self_factor = pd.Series([], dtype = float)
siom_others_factor = pd.Series([], dtype = float)
for name, group in nba_groups:
    siom_self_factor = siom_self_factor.append(((1 - (group['shotqualityavg']))*(group['efg%'] - lg_avg_teamstats.loc[name, 'efg%'])
                            *(group['ptsunassisted2s'] + group['ptsunassisted3s'])) + (group['ft%'] - 
                            (lg_avg_teamstats.loc[name, 'ft'])/lg_avg_teamstats.loc[name, 'fta'])*group['ftpoints'])
    siom_others_factor = siom_others_factor.append((1.5 - (group['tov%']/lg_avg_teamstats.loc[name, 'tov%']))
                                *((group['atrimassists']*(expected_values_by_loc.loc[name,'ev_0to3ft']))
                                + (group['shortmidrangeassists']*(expected_values_by_loc.loc[name,'estev_3to16ft']))
                                + (group['longmidrangeassists']*(expected_values_by_loc.loc[name,'ev_16ftto3pt']))
                                + (group['corner3assists']*(expected_values_by_loc.loc[name,'ev_3pt_corner']))
                                + (group['arc3assists']*(expected_values_by_loc.loc[name,'ev_3pt_arc']))))
nba['siom_self_factor'] = siom_self_factor
nba['siom_others_factor'] = (0.10018018018018018)*siom_others_factor
nba['siom_unadjusted'] = nba['siom_self_factor'] + nba['siom_others_factor']
# Adjusting for player USG%..
nba['uSIOM'] = (1 - np.log(nba['usg%']/20))*nba['siom_unadjusted']
# Adjusting for pace...
nba['pace_estimate'] = (48*nba['offposs'])/nba['mp']
nba_groups = nba.groupby('season')
unstded_SIOM = pd.Series([], dtype = float)
for name, group in nba_groups:
    unstded_SIOM = unstded_SIOM.append((1-np.log(group['pace_estimate']/lg_avg_teamstats.loc[name,'pace']))*group['uSIOM'])
nba['unstded_SIOM'] = unstded_SIOM

# %%
nba.sort_values(by = 'unstded_SIOM', ascending = False)
# Out:
#       season            player  age team   g  gs    gs%    mp   per    ts%  \
# 2332    2008        Chris Paul   22  NOP  80  80  1.000  3006  28.3  0.576
# 1515    2006  Chauncey Billups   29  DET  81  81  1.000  2925  23.4  0.602
# 4564    2015        Chris Paul   29  LAC  82  82  1.000  2857  26.0  0.596
# 3263    2011        Chris Paul   25  NOP  80  80  1.000  2880  23.7  0.578
# 171     2001      Jeff McInnis   26  LAC  81  81  1.000  2831  15.6  0.521
# ...      ...               ...  ...  ...  ..  ..    ...   ...   ...    ...
# 3956    2013    Jamaal Tinsley   34  UTA  66  32  0.485  1221  10.6  0.467
# 3974    2013       Earl Watson   33  UTA  48   4  0.083   829   7.7  0.366
# 4910    2016       Rajon Rondo   29  SAC  72  72  1.000  2537  16.9  0.506
# 5808    2019    Draymond Green   28  GSW  66  66  1.000  2065  12.9  0.526
# 6489    2021    Draymond Green   30  GSW  63  63  1.000  1982  13.3  0.556
#
#       ...  longmidrangeassists  corner3assists  arc3assists  pos  \
# 2332  ...                  223             103          170    G
# 1515  ...                  240              51          103    G
# 4564  ...                  220              76          156    G
# 3263  ...                  261              63          108    G
# 171   ...                  111              13           86    G
# ...   ...                  ...             ...          ...  ...
# 3956  ...                   61              20           51    G
# 3974  ...                   44               3           18    G
# 4910  ...                  149              60          135    G
# 5808  ...                   72              39          122    F
# 6489  ...                   25              49          165    F
#
#       siom_self_factor  siom_others_factor  siom_unadjusted       uSIOM  \
# 2332         46.967606          566.939917       613.907523  459.964859
# 1515         75.350608          430.541803       505.892411  437.392232
# 4564         69.653072          477.539511       547.192584  454.310596
# 3263         40.601726          370.859015       411.460741  389.430817
# 171          13.513673          344.668309       358.181982  391.962368
# ...                ...                 ...              ...         ...
# 3956         -3.003020         -215.809219      -218.812239 -311.396083
# 3974         -4.562309         -203.615015      -208.177324 -332.633431
# 4910        -17.507267         -332.388159      -349.895426 -371.545347
# 5808         -5.688402         -329.742500      -335.430902 -477.358440
# 6489         -1.237077         -656.552000      -657.789077 -936.112820
#
#       pace_estimate  unstded_SIOM
# 2332      91.033932    466.815880
# 1515      86.547692    456.923647
# 4564      94.941547    449.299086
# 3263      89.183333    401.963000
# 171       89.099258    401.526163
# ...             ...           ...
# 3956      89.316953   -320.612554
# 3974      91.599517   -334.084569
# 4910     100.673236   -353.110270
# 5808     101.206780   -471.632258
# 6489     102.926337   -901.593151
#
# [6717 rows x 81 columns]

# %% [markdown]
# Note that in the above output, there was no weight on either `siom_self_factor` or `siom_others_factor` when computing `unstded_SIOM`. By the output above, without performing further analysis, we can tell that `siom_others_factor` must have a disproportionate influence on any given player's `unstded_SIOM`. So, in the next two cells, we will attempt to find the optimal weight for `siom_others_factor` before standardizing our statistic by season. The new weight will be used in the cell where `unstded_SIOM` is calculated, however, the above output was obtained utilizing no weight on `siom_others_factor`.

# %%
# Finding optimal weight for "si_others_factor"...
possible_coeffs = list(np.linspace(0.01,1,1000))
pct_influence = pd.DataFrame([pd.Series(np.zeros(1000)), pd.Series(np.zeros(1000))],
                             columns = ['siom_self', 'siom_others'],
                             dtype = float)
summed_siom_self_factor = sum(nba['siom_self_factor'])
for i in range(0,1000):
    alt_siom_others_factor = possible_coeffs[i]*nba['siom_others_factor']
    summed_alt_siom_others_factor = sum(alt_siom_others_factor)
    summed_unadj_siom = summed_siom_self_factor + summed_alt_siom_others_factor
    pct_influence.loc[i,'siom_self'] = summed_siom_self_factor/summed_unadj_siom
    pct_influence.loc[i,'siom_others'] = summed_alt_siom_others_factor/summed_unadj_siom
pct_influence
# Out:
#      siom_self  siom_others
# 0     0.732785     0.267215
# 1     0.713881     0.286119
# 2     0.695928     0.304072
# 3     0.678856     0.321144
# 4     0.662601     0.337399
# ..         ...          ...
# 995   0.026795     0.973205
# 996   0.026769     0.973231
# 997   0.026743     0.973257
# 998   0.026717     0.973283
# 999   0.026691     0.973309
#
# [1000 rows x 2 columns]

# %% [markdown]
# In the cell above, we found the percent influence of `siom_self_factor` and `siom_others_factor` when multiplying `siom_others_factor` by 1000 different possible coefficients before adding the two to retrive resultant unadjusted SIOM values.
#
# Now, in the cell below, we will find the absolute difference between the percent influence of both factors and find the sensible weights to place on `siom_others_factor`.

# %%
pct_influence['diff'] = abs(pct_influence['siom_self'] - pct_influence['siom_others'])
print(pct_influence.describe())
print(pct_influence[pct_influence['diff'] <= .6])
# Out:
#          siom_self  siom_others         diff
# count  1000.000000  1000.000000  1000.000000
# mean      0.092047     0.907953     0.823527
# std       0.106533     0.106533     0.181357
# min       0.026691     0.267215     0.007505
# 25%       0.035161     0.903752     0.807505
# 50%       0.051506     0.948494     0.896988
# 75%       0.096248     0.964839     0.929677
# max       0.732785     0.973309     0.946618
#      siom_self  siom_others      diff
# 0     0.732785     0.267215  0.465571
# 1     0.713881     0.286119  0.427762
# 2     0.695928     0.304072  0.391856
# 3     0.678856     0.321144  0.357711
# 4     0.662601     0.337399  0.325201
# ..         ...          ...       ...
# 96    0.206876     0.793124  0.586248
# 97    0.205341     0.794659  0.589319
# 98    0.203828     0.796172  0.592344
# 99    0.202338     0.797662  0.595324
# 100   0.200869     0.799131  0.598262
#
# [101 rows x 3 columns]

# %%
print('Absolute percent influence difference with no weight: {:.4f}.'.format(pct_influence.loc[999, 'diff']))
print('Absolute percent influence difference with selected coefficient({:.4f}):' 
      ' {:.4f}.'.format(possible_coeffs[91], pct_influence.loc[91,'diff']))
# Out:
# Absolute percent influence difference with no weight: 0.9466.
# Absolute percent influence difference with selected coefficient(0.1002): 0.5702.

# %% [markdown]
# After some trial and error, we settled on the above coefficient. Using it, we've now calculated `unstded_SIOM` using the exact formulas presented in the cell where the metric was found. Note that the number at the 92nd position of the Series `possible_coeffs` is equal to the weight on `siom_others_factor` five cells above this one. It had be hard coded in due to the order that our cells were executed.
#
# Now, in the below cell, we will standardize SIOM by season. This is important as our statistic is a measure of player skill, which is fundamentally relative to the other athletes they are competing against.

# %%
# Since this metric is seasonal, let's make it standardized by season...
scaler = StandardScaler()
r_siom = pd.Series([], dtype = float)
for name, group in nba_groups:
    arr0 = (group['unstded_SIOM'].values).reshape(-1,1)
    r_siom = r_siom.append(pd.Series(scaler.fit_transform(arr0).flatten()))
r_siom = r_siom.reset_index()
r_siom = pd.Series(r_siom.iloc[:,1])
nba['rSIOM'] = r_siom

# %% [markdown]
# Finally, now the computation of our statistic, `rSIOM`, is complete, we will take a look the 25 best and worst `rSIOM` player seasons over the next 3 cells.

# %%
sorted_by_rSIOM_rank = nba.sort_values(by = 'rSIOM', ascending = False)
sorted_by_rSIOM_rank
# Out:
#       season            player  age team   g  gs  gs%    mp   per    ts%  ...  \
# 4564    2015        Chris Paul   29  LAC  82  82  1.0  2857  26.0  0.596  ...
# 1515    2006  Chauncey Billups   29  DET  81  81  1.0  2925  23.4  0.602  ...
# 3579    2012        Chris Paul   26  LAC  60  60  1.0  2181  27.0  0.581  ...
# 6224    2020    Damian Lillard   29  POR  66  66  1.0  2474  26.9  0.676  ...
# 3761    2013      Kevin Durant   24  OKC  81  81  1.0  3119  28.3  0.647  ...
# ...      ...               ...  ...  ...  ..  ..  ...   ...   ...    ...  ...
# 5808    2019    Draymond Green   28  GSW  66  66  1.0  2065  12.9  0.526  ...
# 3815    2013     Dwight Howard   27  LAL  76  76  1.0  2722  19.4  0.573  ...
# 4496    2015    DeAndre Jordan   26  LAC  82  82  1.0  2820  21.0  0.638  ...
# 4827    2016    DeAndre Jordan   27  LAC  77  77  1.0  2598  20.6  0.628  ...
# 6489    2021    Draymond Green   30  GSW  63  63  1.0  1982  13.3  0.556  ...
#
#       arc3assists  pos  siom_self_factor  siom_others_factor  siom_unadjusted  \
# 4564          156    G         69.653072           47.839994       117.493067
# 1515          103    G         75.350608           43.131755       118.482363
# 3579          108    G         42.553369           41.401942        83.955311
# 6224          132    G         71.746661           38.171620       109.918281
# 3761           82    F        126.993598           20.473773       147.467371
# ...           ...  ...               ...                 ...              ...
# 5808          122    F         -5.688402          -33.033663       -38.722065
# 3815           41    C        -81.284566            3.345497       -77.939069
# 4496           18    C        -49.444779            3.361331       -46.083448
# 4827           16    C        -76.921487            5.500869       -71.420618
# 6489          165    F         -1.237077          -65.773498       -67.010575
#
#            uSIOM  pace_estimate  unstded_SIOM     rSIOM  ptsunassisted
# 4564   97.549467      94.941547     96.473397  5.521076            998
# 1515  102.439302      86.547692    107.013650  5.037713            635
# 3579   67.605512      89.001376     69.329382  4.911272            738
# 6224   64.256530     100.966855     63.830727  4.607361           1214
# 3761   88.660905      93.491504     87.235062  4.537324            736
# ...          ...            ...           ...       ...            ...
# 5808  -55.106147     101.206780    -54.445118 -4.221242             93
# 3815  -69.805346      93.372520    -68.771633 -4.454881            284
# 4496  -63.856105      93.787234    -63.932837 -4.480182            237
# 4827  -90.087451      95.390300    -90.473547 -5.766957            156
# 6489  -95.364092     102.926337    -91.847490 -6.972954            107
#
# [6717 rows x 83 columns]

# %% [markdown]
# In the above cell, we create and display a DataFrame that is the same as our nba DataFrame, except the observations are sorted by their `rSIOM` value in descending order.

# %%
sorted_by_rSIOM_rank.head(25)
# Out:
#       season            player  age team   g  gs    gs%    mp   per    ts%  \
# 4564    2015        Chris Paul   29  LAC  82  82  1.000  2857  26.0  0.596
# 1515    2006  Chauncey Billups   29  DET  81  81  1.000  2925  23.4  0.602
# 3579    2012        Chris Paul   26  LAC  60  60  1.000  2181  27.0  0.581
# 6224    2020    Damian Lillard   29  POR  66  66  1.000  2474  26.9  0.676
# 3761    2013      Kevin Durant   24  OKC  81  81  1.000  3119  28.3  0.647
# 2137    2008  Chauncey Billups   31  DET  78  78  1.000  2522  23.6  0.619
# 1128    2004   Peja Stojakovic   26  SAC  81  81  1.000  3264  21.8  0.624
# 2759    2010  Chauncey Billups   33  DEN  73  73  1.000  2490  20.2  0.601
# 2461    2009  Chauncey Billups   32  TOT  79  79  1.000  2789  18.8  0.592
# 6285    2020        Chris Paul   34  OKC  70  70  1.000  2208  21.7  0.650
# 1201    2005  Chauncey Billups   28  DET  80  80  1.000  2866  19.0  0.609
# 1827    2007  Chauncey Billups   30  DET  70  70  1.000  2533  21.3  0.591
# 5879    2019    Damian Lillard   28  POR  80  80  1.000  2838  23.7  0.588
# 3905    2013        Chris Paul   27  LAC  70  70  1.000  2335  26.4  0.594
# 4402    2015     Stephen Curry   26  GSW  80  80  1.000  2613  28.0  0.638
# 2159    2008     Jose Calderon   26  TOR  82  56  0.683  2484  20.5  0.607
# 3263    2011        Chris Paul   25  NOP  80  80  1.000  2880  23.7  0.578
# 777     2003        Steve Nash   28  DAL  82  82  1.000  2711  22.6  0.576
# 2       2001         Ray Allen   25  MIL  82  82  1.000  3129  22.9  0.610
# 485     2002        Steve Nash   27  DAL  82  82  1.000  2837  20.7  0.602
# 1070    2004        Steve Nash   29  DAL  78  78  1.000  2612  20.5  0.590
# 2332    2008        Chris Paul   22  NOP  80  80  1.000  3006  28.3  0.576
# 6059    2020      Devin Booker   23  PHX  70  70  1.000  2512  20.6  0.668
# 4730    2016     Stephen Curry   27  GSW  79  79  1.000  2700  31.5  0.669
# 5518    2018    Damian Lillard   27  POR  73  73  1.000  2670  25.2  0.594
#
#       ...  arc3assists  pos  siom_self_factor  siom_others_factor  \
# 4564  ...          156    G         69.653072           47.839994
# 1515  ...          103    G         75.350608           43.131755
# 3579  ...          108    G         42.553369           41.401942
# 6224  ...          132    G         71.746661           38.171620
# 3761  ...           82    F        126.993598           20.473773
# 2137  ...           85    G         74.009720           27.076535
# 1128  ...           24    F         84.123148           14.483839
# 2759  ...           58    G         69.721653           22.363884
# 2461  ...           90    G         58.721891           28.186542
# 6285  ...          147    G         43.242880           22.716512
# 1201  ...           56    G         60.736823           20.483592
# 1827  ...           61    G         50.427640           31.951557
# 5879  ...          120    G         67.155944           40.251768
# 3905  ...          115    G         48.942230           36.946450
# 4402  ...          115    G         90.480096           28.500071
# 2159  ...          131    G         37.580039           29.125420
# 3263  ...          108    G         40.601726           37.152723
# 777   ...          112    G         63.155186           33.027718
# 2     ...           62    G         72.932453           23.539989
# 485   ...          113    G         65.463272           21.915359
# 1070  ...          133    G         56.471708           16.267826
# 2332  ...          170    G         46.967606           56.796143
# 6059  ...          128    G         72.908461           17.736815
# 4730  ...          122    G        118.562597           30.575993
# 5518  ...          108    G         73.451140           35.068781
#
#       siom_unadjusted       uSIOM  pace_estimate  unstded_SIOM     rSIOM  \
# 4564       117.493067   97.549467      94.941547     96.473397  5.521076
# 1515       118.482363  102.439302      86.547692    107.013650  5.037713
# 3579        83.955311   67.605512      89.001376     69.329382  4.911272
# 6224       109.918281   64.256530     100.966855     63.830727  4.607361
# 3761       147.467371   88.660905      93.491504     87.235062  4.537324
# 2137       101.086255   86.958243      87.226011     91.969160  4.490628
# 1128        98.606987   81.040529      93.544118     78.000455  4.231372
# 2759        92.085537   74.152424      94.033735     73.093147  4.068920
# 2461        86.908433   79.818444      93.366798     78.380641  4.065216
# 6285        65.959391   55.886001      98.260870     57.033890  4.055804
# 1201        81.220415   78.426317      87.424983     81.483290  4.027459
# 1827        82.379197   76.421479      87.358863     80.294255  3.964742
# 5879       107.407712   66.393514      99.890063     66.466545  3.921007
# 3905        85.888681   75.391570      90.819700     76.365052  3.910779
# 4402       118.980168   75.182459     100.059701     70.405618  3.895762
# 2159        66.705459   78.335782      89.700483     80.658502  3.879919
# 3263        77.754449   73.591416      89.183333     75.959644  3.875842
# 777         96.182904   77.056851      93.485799     74.980167  3.833465
# 2           96.472443   77.288815      93.131352     75.753851  3.824733
# 485         87.378630   75.166423      94.155798     72.355689  3.817803
# 1070        72.739534   74.581139      94.658499     70.900150  3.801391
# 2332       103.763749   77.744085      91.033932     78.902056  3.785081
# 6059        90.645276   53.891779     101.082803     53.472808  3.766826
# 4730       149.138589   76.272455     101.351111     71.976169  3.766076
# 5518       108.519921   62.369900      97.366292     62.327421  3.743786
#
#       ptsunassisted
# 4564            998
# 1515            635
# 3579            738
# 6224           1214
# 3761            736
# 2137            579
# 1128            331
# 2759            580
# 2461            643
# 6285            791
# 1201            451
# 1827            525
# 5879           1100
# 3905            682
# 4402            844
# 2159            523
# 3263            743
# 777             789
# 2               567
# 485             790
# 1070            626
# 2332           1053
# 6059            733
# 4730           1037
# 5518           1030
#
# [25 rows x 83 columns]

# %%
sorted_by_rSIOM_rank.tail(25)
# Out:
#       season           player  age team   g  gs    gs%    mp   per    ts%  \
# 1470    2005      Ben Wallace   30  DET  74  74  1.000  2671  17.4  0.459
# 5011    2017  Bismack Biyombo   24  ORL  81  27  0.333  1793  12.2  0.546
# 5132    2017    Dwight Howard   31  ATL  74  74  1.000  2199  20.8  0.627
# 1151    2004      Ben Wallace   29  DET  81  81  1.000  3050  17.3  0.441
# 4566    2015    Elfrid Payton   20  ORL  82  63  0.768  2489  13.8  0.456
# 2566    2009    Dwight Howard   23  ORL  79  79  1.000  2821  25.4  0.600
# 3280    2011      Rajon Rondo   24  BOS  68  68  1.000  2527  17.1  0.495
# 2248    2008    Dwight Howard   22  ORL  82  82  1.000  3088  22.9  0.619
# 2871    2010    Dwight Howard   24  ORL  82  82  1.000  2843  24.0  0.630
# 3764    2013     Reggie Evans   32  BKN  80  56  0.700  1967  12.8  0.506
# 2205    2008     Reggie Evans   27  PHI  81  61  0.753  1879  11.0  0.463
# 5471    2018    Dwight Howard   32  CHA  81  81  1.000  2463  20.5  0.577
# 2089    2007      Ben Wallace   32  CHI  77  77  1.000  2697  14.6  0.456
# 4910    2016      Rajon Rondo   29  SAC  72  72  1.000  2537  16.9  0.506
# 3492    2012    Dwight Howard   26  ORL  54  54  1.000  2070  24.2  0.569
# 4802    2016    Dwight Howard   30  HOU  71  71  1.000  2280  18.9  0.604
# 3650    2012      Earl Watson   32  UTA  50   2  0.040  1033   9.5  0.413
# 4163    2014   DeAndre Jordan   25  LAC  82  82  1.000  2870  18.2  0.630
# 5155    2017   DeAndre Jordan   28  LAC  81  81  1.000  2570  21.8  0.673
# 4741    2016   Andre Drummond   22  DET  81  81  1.000  2666  21.2  0.499
# 5808    2019   Draymond Green   28  GSW  66  66  1.000  2065  12.9  0.526
# 3815    2013    Dwight Howard   27  LAL  76  76  1.000  2722  19.4  0.573
# 4496    2015   DeAndre Jordan   26  LAC  82  82  1.000  2820  21.0  0.638
# 4827    2016   DeAndre Jordan   27  LAC  77  77  1.000  2598  20.6  0.628
# 6489    2021   Draymond Green   30  GSW  63  63  1.000  1982  13.3  0.556
#
#       ...  arc3assists  pos  siom_self_factor  siom_others_factor  \
# 1470  ...           22    C        -45.456894           10.107411
# 5011  ...           24    C        -29.162380            0.798553
# 5132  ...           16    C        -42.326025            1.366727
# 1151  ...           15    C        -43.100775            8.968214
# 4566  ...           89    G        -38.387673           -1.037861
# 2566  ...           50    C        -70.887429            4.505402
# 3280  ...           94    G        -17.973991          -25.446866
# 2248  ...           24    C        -68.535043            3.390926
# 2871  ...           60    C        -52.787166            1.476010
# 3764  ...            7    F        -28.316418           -1.023903
# 2205  ...            5    F        -37.264241            0.402755
# 5471  ...           34    C        -56.461441            3.807195
# 2089  ...           22    C        -40.575339            7.569355
# 4910  ...          135    G        -17.507267          -33.298706
# 3492  ...           57    C        -55.995351            4.270779
# 4802  ...           28    C        -51.874115            2.298501
# 3650  ...           14    G         -6.869022          -19.069557
# 4163  ...           14    C        -39.315409            3.023513
# 5155  ...           30    C        -45.264158            4.443766
# 4741  ...           17    C        -78.991287            5.065351
# 5808  ...          122    F         -5.688402          -33.033663
# 3815  ...           41    C        -81.284566            3.345497
# 4496  ...           18    C        -49.444779            3.361331
# 4827  ...           16    C        -76.921487            5.500869
# 6489  ...          165    F         -1.237077          -65.773498
#
#       siom_unadjusted      uSIOM  pace_estimate  unstded_SIOM     rSIOM  \
# 1470       -35.349483 -45.050683      87.427930    -46.805191 -3.069136
# 5011       -28.363828 -40.149436      92.733965    -41.706086 -3.082033
# 5132       -40.959298 -42.631339      96.196453    -42.721449 -3.146430
# 1151       -34.132561 -43.275972      88.382951    -44.108649 -3.163333
# 4566       -39.425534 -42.927752      93.512254    -43.105383 -3.181599
# 2566       -66.382027 -48.710929      91.831266    -48.641251 -3.238894
# 3280       -43.420857 -47.277984      91.365255    -47.656666 -3.260233
# 2248       -65.144117 -52.726322      94.259067    -51.676011 -3.265373
# 2871       -51.311157 -42.170270      91.120647    -42.894926 -3.267600
# 3764       -29.340322 -46.881051      87.361464    -49.306410 -3.332908
# 2205       -36.861486 -51.077578      88.285258    -53.404358 -3.358694
# 5471       -52.654246 -42.617275      98.026797    -42.300122 -3.402348
# 2089       -33.005984 -53.960766      92.956618    -53.343892 -3.465958
# 4910       -50.805973 -53.949613     100.673236    -51.272779 -3.466539
# 3492       -51.724572 -37.955334      89.043478    -38.905205 -3.493815
# 4802       -49.575615 -53.709309      96.126316    -53.526674 -3.598804
# 3650       -25.938580 -40.292607      90.145208    -40.805491 -3.641384
# 4163       -36.291896 -53.640721      95.063415    -52.980200 -3.716538
# 5155       -40.820391 -51.755335      95.514397    -52.232996 -3.749670
# 4741       -73.925935 -60.140259      94.433608    -61.004213 -4.037609
# 5808       -38.722065 -55.106147     101.206780    -54.445118 -4.221242
# 3815       -77.939069 -69.805346      93.372520    -68.771633 -4.454881
# 4496       -46.083448 -63.856105      93.787234    -63.932837 -4.480182
# 4827       -71.420618 -90.087451      95.390300    -90.473547 -5.766957
# 6489       -67.010575 -95.364092     102.926337    -91.847490 -6.972954
#
#       ptsunassisted
# 1470            216
# 5011             66
# 5132            266
# 1151            240
# 4566            479
# 2566            546
# 3280            436
# 2248            376
# 2871            514
# 3764            106
# 2205            107
# 5471            436
# 2089            156
# 4910            528
# 3492            412
# 4802            216
# 3650             71
# 4163            178
# 5155            228
# 4741            520
# 5808             93
# 3815            284
# 4496            237
# 4827            156
# 6489            107
#
# [25 rows x 83 columns]

# %% [markdown]
# ### II. Preregistered Analyses

# %% [markdown]
# #### A. Multi-Class Logistic Classificaiton of Player Position on rSIOM
#
# Here, we use a multi-class logistic regression model to attempt to classify a player's position (`pos`) given their `rSIOM` value. We do this to see if our statistic is biased in any way, namely by over- or under-predicting a certain position. In this first cell, we divide our data into training and testing sets so that we have some data on which to fit the model and some unseen data on which to test its predictive power.

# %%
# train-test split (75%/25%)
Xl_train, Xl_test, yl_train, yl_test = train_test_split(
    nba[['rSIOM']], 
    nba['pos'], 
    test_size= 0.25
)
print('Length of training data set: {} \nLength of test data set:'.format(len(yl_train)),len(yl_test))
# Out:
# Length of training data set: 5037
# Length of test data set: 1680

# %%
# Setting up logistic model
lm = LogisticRegression(multi_class = 'multinomial', solver = 'sag')
logistic = lm.fit(Xl_train, yl_train)
lm_score = logistic.score(Xl_test, yl_test)
print('Score of fitting the model on one instance of training and test data subsets: {: .4f}'.format(lm_score))
# Out:
# Score of fitting the model on one instance of training and test data subsets:  0.4851

# %% [markdown]
# In the cell above, we use the training and testing subsets of the data that we created to fit the logistic regression model. We then test that fitted model on data that the model has not yet seen in order to see its predictive capabilities.
#
# In the cell below, we use cross-validation to repeat that same process 30 times with varying training and testing subsets to achieve a better expected accuracy from the model.

# %%
scores_log = cross_val_score(lm,nba[['rSIOM']],nba['pos'],cv=30)
print('Mean cross-validated accuracy: {:.4f}'.format(scores_log.mean()))
# Out:
# Mean cross-validated accuracy: 0.4895

# %% [markdown]
# Guards are the most common position in the dataset, making up 44.39% of all players. Therefore, if someone were just to guess that a player is a guard, regardless of their `rSIOM` value, they would have a 44.39% chance of being correct. The logisitic regression model above had a slightly better accuracy of around 49%.

# %%
# Baseline guess of most common position (G)
baseline_guess_rate = (sum(nba.pos == "G"))/len(nba)
print('Baseline guess rate: {:.4f}'.format((sum(nba.pos == "G"))/len(nba)))
# Out:
# Baseline guess rate: 0.4439

# %% [markdown]
# In the 2 cells below, we measure and visualize the accuracy of our multi-class logistic classifier. First, we use a confusion matrix to identify the instances in which our model correctly and incorrectly labeled a player's position. From this matrix, it is clear that the model most commonly predicted players to be guards.
#
# The classification report supplements this confusion matrix and provides new metrics for measuring the models accuracy. From the classification report, we know that our model correctly predicted the position of centers roughly 46% of the time, forwards roughly 36% of the time, and guards roughly 51% of the time when it predicted those labels. Additionally, interestingly, the recall of our model varied greatly by position group, with a recall of about 34% for centers, about 8% for forwards, and about 86% for guards.

# %%
# True labels and predicted labels
yl_true = nba.pos
yl_pred_full = logistic.predict(nba[['rSIOM']])

# Confusion Matrix
disp = ConfusionMatrixDisplay(
    confusion_matrix(yl_true, yl_pred_full), 
    display_labels = nba.pos.unique()
)
disp.plot()
plt.title('Confusion Matrix')
plt.xticks(ticks = [0,1,2], labels = ['C','F','G'])
plt.yticks(ticks = [0,1,2], labels = ['C','F','G'])
plt.show()

# %%
# Classification Report
print(classification_report(yl_true, yl_pred_full))
obs_f1score = f1_score(yl_true, yl_pred_full, average = 'micro')
# Out:
#               precision    recall  f1-score   support
#
#            C       0.46      0.34      0.39      1599
#            F       0.37      0.05      0.09      2136
#            G       0.50      0.88      0.64      2982
#
#     accuracy                           0.49      6717
#    macro avg       0.45      0.43      0.38      6717
# weighted avg       0.45      0.49      0.41      6717

# %% [markdown]
# #### B. Multivariate Regression of Offensive Box Plus-Minus with Unassisted Points, Assist Points, and True Shooting Percentage as the Input Variables
#
# Below, we utilize multivariate linear regression of Offensive Box Plus-Minus (`obpm`) on unassisted points (`ptsunassisted`), assist points (`assistpoints`), and true shooting percentage (`ts%`) to inform the creation of our statistic, `rSIOM`.

# %%
# train-test split (75%/25%)
nba['ptsunassisted'] = nba.ptsunassisted2s + nba.ptsunassisted3s
Xm_train, Xm_test, ym_train, ym_test = train_test_split(
    nba[['ptsunassisted','assistpoints','ts%']], 
    nba['obpm'], 
    test_size= 0.25
)
print('Length of training data set: {} \nLength of test data set:'.format(len(ym_train)), len(ym_test))
# Out:
# Length of training data set: 5037
# Length of test data set: 1680

# %%
# Fitting, predicting, and plotting the results of the multivariate linear model
multi_lr = LinearRegression()
multi_lin = multi_lr.fit(Xm_train,ym_train)
ym_pred = multi_lin.predict(Xm_test)

# Plotting predicted offensive box plus/minus vs. actual obpm
plt.scatter(
    ym_test,
    ym_pred,
    alpha = 0.3
)
plt.plot(
    np.linspace(-20,20),
    np.linspace(-20,20),
    linestyle='dashed',
    linewidth=2,
    color = 'black',
)
plt.xlabel('Actual OBPM')
plt.ylabel('Predicted OBPM')
plt.title('Predicted vs. Actual OBPM')
plt.show()

# %% [markdown]
# Above is a scatterplot of the true and the predicted offensive box plus/minus values. The black, dashed line would indicate a perfect prediction for any dots on it.
#
# Below, we use cross validation to assess the accuracy of this multivariate linear regression model.

# %%
scores_multi = cross_val_score(multi_lr, nba[['ptsunassisted','assistpoints','ts%']], nba['obpm'],cv=30)
print('Mean cross-validated accuracy: {:.4f}'.format(scores_multi.mean()))
# Out:
# Mean cross-validated accuracy: 0.6722

# %% [markdown]
# ### III. Additional Analyses

# %% [markdown]
# #### Linear Regression of Team Offensive Rating on the Maximum rSIOM value per team and season

# %% [markdown]
# In the following cells, we create a linear regression model to find the relationship between our statistic, `rSIOM` and the offensive rating of that player's team. More specifically, we find the player on every team in each season in our dataset with the highest `rSIOM` value. Then, for that given player on each team in each season, we regress that team's offensive rating (`ortg`) on our statistic. This attempts to quantify the relationship between the "best" player on a given team and that team's overall offensive performance, revealing the true impact of a team's offensive star.

# %%
# Merging nba and teamstats subsets to get team offensive rating for a given player and season
teamstats_sub = teamstats.reset_index().loc[:,['season','team','ortg']]
nba_sub = nba.loc[:,['season','team','player','rSIOM']]
nba_sub = nba_sub.merge(teamstats_sub, how = 'inner', on = ['season','team'])
# Retrieving the best rSIOM value for a given team and a given year
best_r_siom = nba_sub.loc[:,['season','team','rSIOM','ortg']].groupby(['season','team']).max()

# %%
# train-test split (75%/25%)
X2_train, X2_test, y2_train, y2_test = train_test_split(
    best_r_siom[['rSIOM']], 
    best_r_siom['ortg'], 
    test_size= 0.25
)
print('Length of training data set: {} \nLength of training data set:'.format(len(y2_train)),len(y2_test))
# Out:
# Length of training data set: 469
# Length of training data set: 157

# %%
# Cross-validating the team offensive ratings with best rSIOM on a given team and season
lr2 = LinearRegression()
lin2 = lr2.fit(X2_train,y2_train)
y2_pred = lr2.predict(X2_test)

# Plotting predicted team offensive ratings vs. actual team offense ratings
plt.scatter(
    y2_test,
    y2_pred,
    alpha = 0.5
)
plt.plot(
    np.linspace(90,120),
    np.linspace(90,120),
    linestyle='dashed',
    linewidth=2,
    color ='black',
)
plt.title('Predicted vs True Team Offensive Rating')
plt.xlabel('True Team ORTG')
plt.ylabel('Predicted Team ORTG')
plt.show()

# %% [markdown]
# The plot above shows the accuracy of our model in predicting each team's offensive rating. The scatterplot reveals that the model systematically overestimated at the lower end of the range and underestimated at the top end of the range.

# %%
# Linear Regression Plot
plt.scatter(
    best_r_siom['rSIOM'],
    best_r_siom['ortg'],
    alpha = 0.4
)

# Plotting the Regression Line (Predicted Team ortg)
plt.plot(
    best_r_siom['rSIOM'],
    best_r_siom['rSIOM']*lin2.coef_ + lin2.intercept_,
    color = 'darkorange',
    linewidth = 3
)
plt.xlabel('Player rSIOM')
plt.ylabel('Team ORTG')
plt.legend(['Predicted ORTG','Individual Observations'])
plt.show()

# %% [markdown]
# The plot above shows the linear relationship between the `rSIOM` value of the best player on a team and that team's offensive rating. While the data is noisy, the regression line indicates a positive relationship.
#
# Below, we use cross-validation to assess the accuracy of our model in predicting a team's offensive rating based on their best player.

# %%
# Cross-validated score of this model
scores_best_r_siom = cross_val_score(lr2,best_r_siom[['rSIOM']], best_r_siom['ortg'], cv = 10)
print('Mean cross-validated accuracy: {:.4f}'.format(scores_best_r_siom.mean()))
# Out:
# Mean cross-validated accuracy: -0.2494

# %% [markdown]
# ## Evaluation of Significance

# %% [markdown]
# ### I. Permutation Test for p-value for Team Offensive Rating vs. the Maximum rSIOM per Team per Season Regression Slope

# %% [markdown]
# In the following cells, we use permuted data to determine the significance of the relationship in our data between a team's offensive rating and that team's player with the highest `rSIOM` score on the team. By permuting the data, we are able to generate the circumstances that would be true under the null hypothesis that there is no effect of a team's best offensive engine on their offensive performance.

# %%
def permute(series):
    perm = series.copy().values
    np.random.shuffle(perm)
    return pd.Series(perm)

def plot_line(df, model, is_resampled=True):
    if is_resampled:
        color = "grey"
        alpha = 0.1
        label = None
    else:
        color = "darkorange"
        alpha = 1
        label = 'True Slope'
    plt.plot(df['rSIOM'], df['rSIOM'] * model.coef_[0] + model.intercept_, color=color, alpha=alpha, label=label)

# %%
# Plot true data
plt.scatter(
    best_r_siom['rSIOM'],
    best_r_siom['ortg'],
    alpha = 0.2
)

# 100 iterations of models on permuted data
for i in range(100):
    permuted_model = LinearRegression().fit(best_r_siom[['rSIOM']], permute(best_r_siom['ortg']))
    plot_line(best_r_siom, permuted_model)


# Model true data and plot
plot_line(best_r_siom, lin2, is_resampled=False)
plt.title('True Relationship vs. Null')
plt.xlabel('Player rSIOM')
plt.legend()
plt.ylabel('Team ORTG')
plt.show()

# %% [markdown]
# In the 3 cells below, we evaluate the significance of this reliationship by finding the percent of slopes under the null hypothesis that are greater than the one found in our data set. This is the p-value of the linear regression model.

# %%
# What fraction of permuted (null hyopthesis) slopes are greater than our observed slope?
steeper_slopes = 0
n_perms = 1000
perm_slopes = np.zeros(n_perms)

for i in range(n_perms):
    perm_model = LinearRegression().fit(best_r_siom[['rSIOM']], permute(best_r_siom['ortg']))
    perm_slopes[i] = perm_model.coef_[0]
    
    if np.abs(perm_model.coef_[0]) > np.abs(lin2.coef_):
        steeper_slopes += 1
print('Percent of slopes steeper than that of our model: {:.4%}'.format(steeper_slopes/n_perms))
# Out:
# Percent of slopes steeper than that of our model: 0.0000%

# %%
# Plot of our slope in relation to the distribution of slopes expected under the null hypothesis
binsizes, _, _ = plt.hist(perm_slopes, bins=50)
plt.vlines(lin2.coef_[0], ymin=0, ymax=np.max(binsizes), color='red')
plt.legend(['Observed Slope','Slopes under Null'])
plt.title('True Slope vs. Slopes under Null')
plt.xlabel('Coefficient of Regression Model')
plt.ylabel('Frequency')
plt.show()

# %%
# Regression table
sm_model = smf.ols("ortg ~ rSIOM", data= best_r_siom)
result = sm_model.fit()

# P-values
print('Analytic p-value: {:.4f}'.format(result.pvalues.rSIOM))
print('Simulated p-value: {:.4f}'.format(steeper_slopes/n_perms))
# Out:
# Analytic p-value: 0.0000
# Simulated p-value: 0.0000

# %% [markdown]
# ### II. Confidence Interval for the Mean $f_1$-Score of Our Multi-Class Logistic Classifier

# %% [markdown]
# In the following cells, we use bootstrapping to find a 99% confidence interval for the mean $f_1$-score of our logistic classifier. By utilizing bootstrapping, we are able to perform our classification many, many times using datasets similar to ours. This allows us to get a range of realistic possibilities for our mean $f_1$-score.

# %%
# Perform many bootstraps...
num_bootstrap = 500
bootstrap_meanf1s = np.zeros(500)
for i in range(num_bootstrap):
    resampled_nba = nba.sample(n=len(nba), replace=True)
    Xr_train, Xr_test, yr_train, yr_test = train_test_split(
    resampled_nba[['rSIOM']], 
    resampled_nba['pos'], 
    test_size= 0.25)
    resampled_logistic = lm.fit(Xr_train, yr_train)
    yr_true = resampled_nba.pos
    yr_pred_full = logistic.predict(resampled_nba[['rSIOM']])
    bootstrap_meanf1s[i] = f1_score(yr_true, yr_pred_full, average = 'micro')

# %%
# Get simulation-derived estimate of 99% confidence interval for mean f_1 score
sim_est_99pct_ci = np.quantile(bootstrap_meanf1s, q=[0.005, 0.995])
print('Simulated 99% Confidence Interval for f1 Score: ({:.4f},{:.4f})'.format(sim_est_99pct_ci[0], sim_est_99pct_ci[1]))
# Out:
# Simulated 99% Confidence Interval for f1 Score: (0.4718,0.5025)

# %%
# plot observed mean f1 score and histogram of resampled mean f1 scores
plt.figure()
binsizes, _, _ = plt.hist(bootstrap_meanf1s, bins=20, color = 'red')
plt.vlines(obs_f1score, ymin=0, ymax=np.max(binsizes), color = 'green')
plt.vlines(sim_est_99pct_ci[0], ymin=0, ymax=np.max(binsizes), color ='black')
plt.vlines(sim_est_99pct_ci[1], ymin=0, ymax=np.max(binsizes), color ='black')
plt.vlines(baseline_guess_rate, ymin=0, ymax=np.max(binsizes), color = 'blue')
plt.title('Distribution of Bootstrap f1 Scores')
plt.legend(['Observed f1 Score','Confidence Interval Lower Bound','Confidence Interval Upper Bound', 
            'Baseline Guess Rate', 'Bootstrap f1 Scores'], fontsize = 'x-small')
plt.show()

# %% [markdown]
# ## Interpretation and Conclusions

# %% [markdown]
# ### I. Model Interpretations
#
# #### A. Multi-Class Logistic Classifier
# Looking at our multi-class logistic classifier, the overall $f_1$-score is in-fact better than the baseline accuracy. Furthermore, as can be seen by our 99% confidence interval for the $f_1$-score, which we found using bootstrapping, we are 99% confident that our $f_1$-score is statistically significant when compared to the baseline accuracy. This is because the baseline accuracy was not apart of our confidence interval. Thus, our classifier does predict player position via our statistic significantly better than the baseline method does. While the difference in predictive power is statistically significant, it may not be tremendously meaningful, based solely on the magnitude of this difference. This could be improved with further optimization of the coefficients on the parameters of the statistic.
#
# Another interesting result is the stark difference in $f_1$-scores across the three positional groups. While the guard and center $f_1$-scores are near the overall $f_1$-score, with the guard one being the best, the forward $f_1$-score was incredibly low. There are a handful of reasons why forwards may have been tricky for the classifier to handle. First, looking at our statistic's top-ranking and bottom-ranking seasons, the top-ranking seasons are almost all guards, while the bottom-ranking ones are almost all centers. Additionally, the forward position in the NBA has changed drastically over the past 20 seasons, and has reached a point where it is now more diverse than ever, meaning that the on-court performance and responsibilities of forwards, and consequently their performance metrics, are not as uniform as they used to be.
#
# #### B. Linear Regression Models
# We used a multivariate linear regression model to determine the impact of certain performance metrics of players on a more broad measure of their offensive productivity, offensive box plus/minus (obpm). The metrics we used in this model were the number of points they scored that were unassisted, which they created themselves, the number of assist points, and their true shooting percentage. The obpm of a player measures their contribution to the team when they are on versus off the court. We estimated this regression to gain a better sense of the impact of these variables on a player's offensive contribution and productivity to inform the creation of our own statistic, rSIOM. The score of 0.6722 means that the model explains 67.22% of the variation in obpm, meaing that these 3 variables are decent predictors of a player's obpm.
#
# In the linear regression model where we regressed a team's offensive rating on the player with the highest value of our statistic, we found a there to be a statistically significant impact of rSIOM on the team's ortg. This relationship estimates the effect of a team's best player on its overall offensive rating, which was a goal of our statistic. We used permutation tests to assess whether or not the estimated effect we observed in the dataset was statistically significant, meaning that we wanted to see whether the observed result was due to random chance or due to an actual underlying relationship in the data. Both measurements of the p-value yielded 0. The analytic p-value was calculated using the standard linear regression model, whereas the simulated p-value was calculated based off of the relationships found in the permuted data. By permuting the data, we can create a distribution of slopes that we could expect to see under the null hypothesis that there is no relationship between a team's best player, based on their rSIOM value, and their offensive rating. This allowed us to ultimately compare the slopes under the null the the slope of the observed relationship, which proved it to be statistically significant. This analysis proves that there is a significant impact of a team's most valuable offensive player on the team's overall offensive rating.
#
# ### Conclusion
# Examining the rSIOM values for various players from different seasons, our statistic seems to be a reasonable representation of a player's ability to induce and convert offensive opportunities for himself, as well as leading teammates to those opportunities. However, the weight of each of its two factors, as well as the weights of the components of these individual factors, could potentially be further optimized to produce a slightly better metric. Our stat seems to greatly reward efficient scoring, and low turnover, efficient shot creation, which was our initial intent. However, it may also favor low turnover rates and penalize high usage rates too much. This can be seen looking at the seasons performance statistics of the top-ranked players according to rSIOM.

# %% [markdown]
# ## Data Limitations

# %% [markdown]
# Sports data tends to be created and maintained relatively well, and our dataset followed this trend. While there are not any true potential harms or data gaps, however, a key limitation of our dataset is the aforementioned fact that it only spans the previous 20 NBA seasons (the 2000-2001 season through the 2020-2021 season). This will not be an issue when our statistic based on this dataset is deployed in the previously mentioned context we envision its primary use to be in, which is for making personnel decisions such as signing a free agent or executing a trade, current season player evaluation, and for game planning purposes. But, it will limit our metric’s use in historical comparisons and all-time player evaluation, as it will only be applied to players who played in the 2000-2001 season or later. However, these historical tasks are not the top priority of the coaches and front offices of today's NBA organizations.
